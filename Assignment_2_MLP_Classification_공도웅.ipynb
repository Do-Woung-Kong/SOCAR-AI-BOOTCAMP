# %% [markdown]
# # Assignment 2. MLP MNIST classification - Finetuning
#
# 이번 과제는 4주차와 5주차에 배운 내용을 이용해 MLP를 구성하고 학습을 진행해 봅니다.
#
# 2가지 종류의 MNIST 데이터에 대해 다양한 모델 구조를 적용해 학습을 진행해 보고 여러 기법들에 따라 어떻게 학습 양상이 달라지는 지 분석해 봅니다.
#
# 여러 모델 구조와 기법들 중에서 최적의 조건을 찾아 성능을 향상 시키는 것이 과제의 목표입니다.
#
# AI 엔지니어로서 여러분은 데이터의 특징을 분석해서 적절한 모델 구조와 다양한 hyper parameter를 결정해야 합니다. 그렇지만 아무리 insight가 좋은 엔지니어라도 데이터만 봐서는 최적의 모델 세팅을 알아낼 수는 없을 겁니다. 다양한 모델을 구성하고 직접 학습을 진행해 봐야 하고 새로운 아이디어도 적용해 볼 수 있어야 합니다.
#
# 5주차 실습에서 사용한 trainer class를 여러분의 입맛에 맞게 변형하여 각자 적용해보고 싶은 기능들의 성능을 확인해 봅시다.
#
# ### 1. Data
#
# 이번 과제는 MNIST와 FMNIST 데이터를 사용합니다.
#
# 그렇지만 다양한 종류의 데이터에 적용할 수 있는 범용적인 코드를 작성하여, 2개의 데이터 셋에 대해 코드의 큰 변형 없이 적용하는 것을 목표로 하겠습니다.
#
# 각 데이터 셋에 대해 다르게 나타날 최적의 hyperparameter setting을 찾아보도록 하겠습니다.
#
# ### 2. Model structure
#
# 기본적인 MLP 구조에서 여러분은 hidden layer를 몇 층 쌓을지, 각 layer의 width, activation function과 dropout, batch normalization의 적용 여부를 결정하셔야 합니다.
#
# 주어진 데이터에 대해 최대의 성능을 내는 어떤 설정이 존재하기는 하겠지만, 이걸 한 번에 찾는 건 어렵겠죠? 심지어 모델 초기화 등에 randomness가 존재하기 때문에 매번 미세하게 달라질 겁니다.
#
# 이러한 randomness까지는 고려하지 않더라도 모델 구조와 다른 세팅을 바꿔가며 각 데이터셋에 대해 학습을 진행하여 test dataset에 대한 성능을 확인해 보도록 하겠습니다.
#
# ### 3. Optimization procedure
#
# 이미 실습에서 확인하셨겠지만 모델 구조 외에도 어떠한 optimizer와 learning rate을 사용하느냐도 성능에 굉장히 큰 영향을 줍니다.
#
# 많이 사용되는 SGD와 Adam optimizer 외에도 다른 알고리즘들을 적용해 보겠습니다.
#
# optimizer의 종류 외에도 각 optimizer의 hyperparameter도 있지만, 이것까지는 tuning을 하지 않아도 될 것 같습니다. 이러한 hyperparameter들은 일반적으로 고정 시켜서 사용하는 추세입니다!
#
# ### 4. 평가
#
# 지금까지 언급한 경우만 고려하더라도 데이터 종류, 모델 종류, optimizer 종류, lr 까지 하여 tuning할 요소가 4가지나 됩니다.
#
# 4종류의 모델, 3종류의 optimizer와 lr을 3가지 확인한다고 하면 이미 72번의 실험을 진행해야겠네요.
#
# 때문에 이렇게 많은 실험들을 효율적으로 정리하고 실행하는 것도 굉장히 중요하답니다.
#
# 이번 과제에서는 for 문을 이용해 여러 번의 실험을 진행한 후 최적의 세팅을 찾아 학습을 한 번 더 진행하는 것으로 하겠습니다.
#
# 실제로는 다양한 hyperparameter에 대한 search를 자동으로 해주는 tool들이 개발되어 있으니 관심 있으신 분들은 찾아보셔도 좋을 것 같습니다. 이번 과제에서는 필요하지 않습니다!

# %% [markdown]
# ### Mount Drive and Import Pacakges

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader

from torchvision import datasets, transforms

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Data

# %% [markdown]
# ### Load and prepare data

# %%
root = os.path.join(os.getcwd(), "drive", "MyDrive", "Colab Notebooks", "data")
root
# Out:
# '/content/drive/MyDrive/Colab Notebooks/data'

# %%
def get_data(data, root, download=True, transform=transforms.ToTensor()):
  if data.lower() == "mnist":
    train = datasets.MNIST(root=root, train=True, download=download, transform=transform)
    test = datasets.MNIST(root=root, train=False, download=download, transform=transform)
  elif data.lower() == "fmnist":
    train = datasets.FashionMNIST(root=root, train=True, download=download, transform=transform)
    test = datasets.FashionMNIST(root=root, train=False, download=download, transform=transform)
  else:
    raise ValueError(f"data name {data} is not supported.")

  return train, test

# %%
mnist_tr, mnist_test = get_data(data="MNIST", root=root)
fmnist_tr, fmnist_test = get_data(data="FMNIST", root=root)

# %% [markdown]
# ### Check datasets

# %%
def plot_mnist(data, figsize=(20, 10)):
  fig = plt.figure(figsize=figsize)
  for i in range(18):
    img = data[i][0]
    ax = fig.add_subplot(3, 6, i+1)
    ax.imshow(img.reshape(28, 28), cmap="gray")
    ax.set_title(f"Label: {data[i][1]}")
  fig.show()
  pass

# %%
plot_mnist(data=mnist_tr)

# %%
plot_mnist(data=fmnist_tr)

# %% [markdown]
# ### Split train dataset into train and valid

# %%
class mnist_dataset(Dataset):
  def __init__(self, data, targets, transform=None, target_transform=None):
    super().__init__()

    self.data = data
    self.targets = targets
    self.transform = transform
    self.target_transform = target_transform
    pass

  def __len__(self):
    return len(self.data)

  def __getitem__(self, idx):
    x, y = self.data[idx], self.targets[idx]

    if self.transform:
      x = self.transform(x)
    if self.target_transform:
      y = self.target_transform(y)

    return x, y

# %%
from sklearn.model_selection import train_test_split

# %%
def split_train_valid(dataset, valid_ratio=0.1):
  train_data,valid_data,train_targets,valid_targets = train_test_split(dataset.data,dataset.targets,test_size=valid_ratio,
                                                                       shuffle=True,random_state=42)
  train = mnist_dataset(data=train_data.numpy(), targets=train_targets, transform=dataset.transform, target_transform=dataset.target_transform)
  valid = mnist_dataset(data=valid_data.numpy(), targets=valid_targets, transform=dataset.transform, target_transform=dataset.target_transform)

  # 이 부분을 채워 보겠습니다.
  # 실습 때 사용한 부분을 그대로 적용하셔도 되지만, 가능하다면 학습 데이터를 random하게 섞은 후에 split을 시도해보겠습니다.
  # 기존의 실습 코드는 데이터의 앞 부분을 train, 뒷 부분을 valid로 사용합니다.
  # 주의하세요, dataset의 data와 targets을 똑같이 shuffle 하셔야 원하는 label을 제대로 지정해 줄 수 있습니다!
  # 시도해 보시고 shuffle이 제대로 안 되는 것 같으면 5주차 실습에 있는 코드를 사용해 주세요.

  return train, valid

# %%
mnist_train, mnist_valid = split_train_valid(dataset=mnist_tr)
fmnist_train, fmnist_valid = split_train_valid(dataset=fmnist_tr)

# %% [markdown]
# ### Check shuffling result

# %%
# 위에서 출력한 결과와 label이 그대로인지 확인해 보세요!
# Shuffle에 성공하셨다면 위와는 다른 그림들이 출력됩니다.
# 각 그림에 해당하는 label은 정확히 적용이 되는지 확인해보세요!
plot_mnist(data=mnist_train)

# %%
plot_mnist(data=fmnist_train)

# %% [markdown]
# ### Get loaders

# %%
# 필요하다면, 후에 이 부분도 수정해 보세요!
# batch size를 바꾸시면 data loader를 다시 만들어야 합니다!
# MNIST는 거의 차이가 없을 것 같은데, FMNIST는 영향을 받을 수도 있습니다!
b_size = 256

# %%
mnist = [DataLoader(dataset=d, batch_size=b_size, shuffle=True, drop_last=True) for d in [mnist_train, mnist_valid, mnist_test]]
fmnist = [DataLoader(dataset=d, batch_size=b_size, shuffle=True, drop_last=True) for d in [fmnist_train, fmnist_valid, fmnist_test]]
datas = {"mnist": mnist, "fmnist": fmnist}

# %% [markdown]
# ## 2. Model

# %% [markdown]
# ### Base model

# %%
class BaseClassifier(nn.Module):
  def __init__(self, n_class=10):
    super().__init__()

    self.name = "base"
    self.model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(28 * 28, 64),
        nn.ReLU(),
        nn.Linear(64, 64),
        nn.ReLU(),
        nn.Linear(64, n_class),
    )

  def forward(self, x):
    return self.model(x)

# %% [markdown]
# ### Customized model1

# %%
class FirstClassifier(nn.Module):
  def __init__(self, n_class=10):
    super().__init__()

    self.name = "first"
    # Model을 만들어 봅시다.
    # 구조와 activation function, 그 외에 다른 기법들의 사용 유무와 사용 위치를 정할 수 있습니다.
    self.model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(28*28, 512),
        nn.BatchNorm1d(512),
        nn.Dropout(p=0.2),
        nn.ReLU(),
        nn.Linear(512, 128),
        nn.BatchNorm1d(128),
        nn.Dropout(p=0.2),
        nn.ReLU(),
        nn.Linear(128,n_class)
    )

  def forward(self, x):
    return self.model(x)

# FirstClassifier 말고도 다양한 모델을 만들어서 학습을 시켜보고 성능을 비교해 볼 수 있습니다.

# %% [markdown]
# ### Customized model2

# %%
class SecondClassifier(nn.Module):
  def __init__(self, n_class=10):
    super().__init__()

    self.name = "second"
    # Model을 만들어 봅시다.
    # 구조와 activation function, 그 외에 다른 기법들의 사용 유무와 사용 위치를 정할 수 있습니다.
    self.model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(28*28, 512),
        nn.BatchNorm1d(512),
        nn.Dropout(p=0.6),
        nn.ReLU(),
        nn.Linear(512, 256),
        nn.BatchNorm1d(256),
        nn.Dropout(p=0.6),
        nn.ReLU(),
        nn.Linear(256, 128),
        nn.BatchNorm1d(128),
        nn.Dropout(p=0.2),
        nn.ReLU(),
        nn.Linear(128,n_class)
    )

  def forward(self, x):
    return self.model(x)

# FirstClassifier 말고도 다양한 모델을 만들어서 학습을 시켜보고 성능을 비교해 볼 수 있습니다.

# %% [markdown]
# ### Using get_model function

# %%
def get_model(model_name):
  if model_name.lower() == "base":
    return BaseClassifier()
  elif model_name.lower() == "first":
    return FirstClassifier()
  elif model_name.lower() == "second":
    return SecondClassifier()
  else:
    raise ValueError(f"model name {model_name} is not supported")

# get_model 함수가 activation function을 받고, 각 classifier를 정의할 때 activation function을 함께 넘겨주도록 만들 수도 있습니다!
# 그렇게 하면 훨씬 적은 수의 model class로 더 다양한 경우를 사용할 수 있을 것 같네요.
# 여러분이 원하는 기능을 가지도록 다양한 model class와 get_model 함수들을 코딩해 보세요!

# %% [markdown]
# ## 3. Trainer

# %% [markdown]
# ### Make trainer

# %%
class Trainer(nn.Module):
  def __init__(self, model, opt, lr, device="cpu"):
    super().__init__()
    self.path = f"_model_{model.name}_opt_{opt}_lr_{lr}"

    self.model = model
    self.loss = nn.CrossEntropyLoss()
    self._get_optimizer(opt=opt.lower(), lr=lr)

    self.device = device
    pass

  def _get_optimizer(self, opt, lr):
    # 몇 가지 optimizer를 더 찾아서 적용해 볼까요?
    if opt == "sgd":
      self.optimizer = torch.optim.SGD(params=self.model.parameters(), lr=lr)
    elif opt == "adam":
      self.optimizer = torch.optim.Adam(params=self.model.parameters(), lr=lr)
    elif opt == "rmsprop":
      self.optimizer = torch.optim.RMSprop(params=self.model.parameters(), lr=lr)
    else:
      raise ValueError(f"optimizer {opt} is not supproted")

  def train(self, data_name, train_loader, valid_loader, max_epochs=100):
    print("===== Train Start =====")
    history = {"train_loss": [], "train_acc": [], "valid_loss": [], "valid_acc": []}
    for e in range(1,max_epochs+1):
      train_loss, train_acc = self._train_epoch(train_loader)
      valid_loss, valid_acc = self._valid_epoch(valid_loader)

      history["train_loss"].append(train_loss)
      history["train_acc"].append(train_acc)
      history["valid_loss"].append(valid_loss)
      history["valid_acc"].append(valid_acc)

      if e % 10 == 0:
        print(f"Epoch: {e}, train loss: {train_loss:>6f}, train acc: {train_acc:>3f}, valid loss: {valid_loss:>6f}, valid acc: {valid_acc:>3f}")

    self.plot_history(history, data_name, max_epochs)

  def _train_epoch(self, train_loader):
    epoch_loss, epoch_acc = 0, 0
    self.model.train()
    for (x, y) in train_loader:
      x = x.to(self.device)
      y = y.to(self.device)

      y_hat = self.model(x)
      loss = self.loss(y_hat, y)

      self.optimizer.zero_grad()
      loss.backward()
      self.optimizer.step()

      epoch_loss += loss.to("cpu").item()
      epoch_acc += (y_hat.argmax(1) == y).type(torch.float).to("cpu").mean().item()

    return epoch_loss / len(train_loader), epoch_acc / len(train_loader)
  
  def _valid_epoch(self, valid_loader):
    epoch_loss, epoch_acc = 0, 0
    self.model.eval()
    with torch.no_grad():
      for (x, y) in valid_loader:
        x = x.to(self.device)
        y = y.to(self.device)

        y_hat = self.model(x)
        loss = self.loss(y_hat, y)

        epoch_loss += loss.to("cpu").item()
        epoch_acc += (y_hat.argmax(1) == y).type(torch.float).to("cpu").mean().item()

    return epoch_loss / len(valid_loader), epoch_acc / len(valid_loader)

  def plot_history(self, history, data_name, max_epochs):
    fig = plt.figure(figsize=(10, 5))

    ax = fig.add_subplot(1, 2, 1)
    ax.plot(history["train_loss"], color="red", label="train loss")
    ax.plot(history["valid_loss"], color="blue", label="valid loss")
    ax.set_title("Loss")
    ax.legend()

    ax = fig.add_subplot(1, 2, 2)
    ax.plot(history["train_acc"], color="red", label="train acc")
    ax.plot(history["valid_acc"], color="blue", label="valid acc")
    ax.set_title("Acc")
    ax.legend()

    path = os.path.join(os.getcwd(), "drive", "MyDrive", "Colab Notebooks", "plots", f"data_{data_name}" + self.path + f"_max_epochs_{max_epochs}.png")
    plt.savefig(path, bbox_inches="tight")
    pass

  def test(self, test_loader):
    print("===== Test Start =====")
    epoch_loss, epoch_acc = 0, 0
    self.model.eval()
    with torch.no_grad():
      for (x, y) in test_loader:
        x = x.to(self.device)
        y = y.to(self.device)

        y_hat = self.model(x)
        loss = self.loss(y_hat, y)

        epoch_loss += loss.to("cpu").item()
        epoch_acc += (y_hat.argmax(1) == y).type(torch.float).to("cpu").mean().item()

    epoch_loss /= len(test_loader)
    epoch_acc /= len(test_loader)

    print(f"Test loss: {epoch_loss:>6f}, Test acc: {epoch_acc:>3f}")

# %% [markdown]
# ### Train and test

# %%
# 해당 코드는 1번만 실행해 주시면 됩니다.
p = os.path.join(os.getcwd(), "drive", "MyDrive", "Colab Notebooks", "plots")
if not os.path.isdir(p):
  os.mkdir(p)

# %% [markdown]
# #### mnist

# %%
ds = ["mnist"]
models = ['base']
opts = ["sgd",'adam','RMSprop']
lrs = [0.001,0.01,0.1]
max_epochs = 25

# %%
for d in ds:
  for m in models:
    for opt in opts:
      for lr in lrs:
        model = get_model(model_name = m)
        trainer = Trainer(model=model, opt=opt, lr=lr)
        print(f"===== Data: {d}, Model: {m}, Optimizer: {opt}, lr: {lr}, max_epochs: {max_epochs} =====")
        trainer.train(data_name=d, train_loader=datas[d][0], valid_loader=datas[d][1], max_epochs=max_epochs)
        trainer.test(test_loader=datas[d][2])
# Out:
# ===== Data: mnist, Model: base, Optimizer: sgd, lr: 0.001, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 2.215145, train acc: 0.406548, valid loss: 2.206408, valid acc: 0.425272
# Epoch: 20, train loss: 1.910049, train acc: 0.535156, valid loss: 1.885389, valid acc: 0.534477
# ===== Test Start =====
# Test loss: 1.589752, Test acc: 0.637921
# ===== Data: mnist, Model: base, Optimizer: sgd, lr: 0.01, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.436933, train acc: 0.878516, valid loss: 0.422290, valid acc: 0.882643
# Epoch: 20, train loss: 0.324558, train acc: 0.907478, valid loss: 0.316179, valid acc: 0.909986
# ===== Test Start =====
# Test loss: 0.288196, Test acc: 0.918870
# ===== Data: mnist, Model: base, Optimizer: sgd, lr: 0.1, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.142751, train acc: 0.958464, valid loss: 0.147882, valid acc: 0.958560
# Epoch: 20, train loss: 0.077558, train acc: 0.978125, valid loss: 0.100768, valid acc: 0.971298
# ===== Test Start =====
# Test loss: 0.089683, Test acc: 0.972656
# ===== Data: mnist, Model: base, Optimizer: adam, lr: 0.001, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.075393, train acc: 0.977809, valid loss: 0.102034, valid acc: 0.967901
# Epoch: 20, train loss: 0.026501, train acc: 0.992783, valid loss: 0.095110, valid acc: 0.973845
# ===== Test Start =====
# Test loss: 0.103814, Test acc: 0.972055
# ===== Data: mnist, Model: base, Optimizer: adam, lr: 0.01, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.044127, train acc: 0.985379, valid loss: 0.123081, valid acc: 0.971807
# Epoch: 20, train loss: 0.039354, train acc: 0.988728, valid loss: 0.179075, valid acc: 0.966712
# ===== Test Start =====
# Test loss: 0.147439, Test acc: 0.973758
# ===== Data: mnist, Model: base, Optimizer: adam, lr: 0.1, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.473071, train acc: 0.881901, valid loss: 0.528092, valid acc: 0.882812
# Epoch: 20, train loss: 1.119621, train acc: 0.692578, valid loss: 1.276406, valid acc: 0.520380
# ===== Test Start =====
# Test loss: 1.054181, Test acc: 0.588942
# ===== Data: mnist, Model: base, Optimizer: RMSprop, lr: 0.001, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.066706, train acc: 0.979967, valid loss: 0.085810, valid acc: 0.974185
# Epoch: 20, train loss: 0.023654, train acc: 0.992894, valid loss: 0.091021, valid acc: 0.976902
# ===== Test Start =====
# Test loss: 0.105564, Test acc: 0.972456
# ===== Data: mnist, Model: base, Optimizer: RMSprop, lr: 0.01, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.089892, train acc: 0.971745, valid loss: 0.123587, valid acc: 0.968240
# Epoch: 20, train loss: 0.059237, train acc: 0.981957, valid loss: 0.173335, valid acc: 0.962976
# ===== Test Start =====
# Test loss: 0.246244, Test acc: 0.957131
# ===== Data: mnist, Model: base, Optimizer: RMSprop, lr: 0.1, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 1.638166, train acc: 0.335844, valid loss: 1.478814, valid acc: 0.360904
# Epoch: 20, train loss: 1.807343, train acc: 0.198121, valid loss: 1.794317, valid acc: 0.207711
# ===== Test Start =====
# Test loss: 1.809496, Test acc: 0.195713

# %%
ds = ["mnist"]
models = ['first','second']
opts = ["sgd",'adam','RMSprop']
lrs = [0.001,0.01,0.1]
max_epochs = 20

# %%
for d in ds:
  for m in models:
    for opt in opts:
      for lr in lrs:
        model = get_model(model_name = m)
        trainer = Trainer(model=model, opt=opt, lr=lr)
        print(f"===== Data: {d}, Model: {m}, Optimizer: {opt}, lr: {lr}, max_epochs: {max_epochs} =====")
        trainer.train(data_name=d, train_loader=datas[d][0], valid_loader=datas[d][1], max_epochs=max_epochs)
        trainer.test(test_loader=datas[d][2])
# Out:
# ===== Data: mnist, Model: first, Optimizer: sgd, lr: 0.001, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.618883, train acc: 0.867057, valid loss: 0.552414, valid acc: 0.889776
# Epoch: 20, train loss: 0.413005, train acc: 0.900409, valid loss: 0.354391, valid acc: 0.916780
# ===== Test Start =====
# Test loss: 0.338309, Test acc: 0.921775
# ===== Data: mnist, Model: first, Optimizer: sgd, lr: 0.01, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.173915, train acc: 0.951935, valid loss: 0.134919, valid acc: 0.961787
# Epoch: 20, train loss: 0.108583, train acc: 0.969810, valid loss: 0.091141, valid acc: 0.972656
# ===== Test Start =====
# Test loss: 0.090211, Test acc: 0.973458
# ===== Data: mnist, Model: first, Optimizer: sgd, lr: 0.1, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.041569, train acc: 0.986998, valid loss: 0.059323, valid acc: 0.982337
# Epoch: 20, train loss: 0.020747, train acc: 0.993676, valid loss: 0.056401, valid acc: 0.982677
# ===== Test Start =====
# Test loss: 0.056359, Test acc: 0.983774
# ===== Data: mnist, Model: first, Optimizer: adam, lr: 0.001, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.024628, train acc: 0.991778, valid loss: 0.057458, valid acc: 0.983186
# Epoch: 20, train loss: 0.013992, train acc: 0.995126, valid loss: 0.052433, valid acc: 0.986243
# ===== Test Start =====
# Test loss: 0.056944, Test acc: 0.983674
# ===== Data: mnist, Model: first, Optimizer: adam, lr: 0.01, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.030513, train acc: 0.989621, valid loss: 0.062997, valid acc: 0.982677
# Epoch: 20, train loss: 0.017561, train acc: 0.994066, valid loss: 0.076957, valid acc: 0.982337
# ===== Test Start =====
# Test loss: 0.083045, Test acc: 0.980369
# ===== Data: mnist, Model: first, Optimizer: adam, lr: 0.1, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.096258, train acc: 0.971856, valid loss: 0.093617, valid acc: 0.979110
# Epoch: 20, train loss: 0.073295, train acc: 0.979074, valid loss: 0.093622, valid acc: 0.979959
# ===== Test Start =====
# Test loss: 0.112783, Test acc: 0.976562
# ===== Data: mnist, Model: first, Optimizer: RMSprop, lr: 0.001, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.027242, train acc: 0.990811, valid loss: 0.053130, valid acc: 0.985394
# Epoch: 20, train loss: 0.014107, train acc: 0.995368, valid loss: 0.059051, valid acc: 0.986753
# ===== Test Start =====
# Test loss: 0.061756, Test acc: 0.983674
# ===== Data: mnist, Model: first, Optimizer: RMSprop, lr: 0.01, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.031186, train acc: 0.989658, valid loss: 0.059130, valid acc: 0.984035
# Epoch: 20, train loss: 0.019607, train acc: 0.993899, valid loss: 0.078106, valid acc: 0.985734
# ===== Test Start =====
# Test loss: 0.072642, Test acc: 0.984475
# ===== Data: mnist, Model: first, Optimizer: RMSprop, lr: 0.1, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.123456, train acc: 0.964602, valid loss: 0.085802, valid acc: 0.976732
# Epoch: 20, train loss: 0.083712, train acc: 0.976749, valid loss: 0.089433, valid acc: 0.979789
# ===== Test Start =====
# Test loss: 0.117386, Test acc: 0.977865
# ===== Data: mnist, Model: second, Optimizer: sgd, lr: 0.001, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 1.479743, train acc: 0.594531, valid loss: 1.292667, valid acc: 0.762908
# Epoch: 20, train loss: 0.963441, train acc: 0.747749, valid loss: 0.757987, valid acc: 0.851393
# ===== Test Start =====
# Test loss: 0.731582, Test acc: 0.861278
# ===== Data: mnist, Model: second, Optimizer: sgd, lr: 0.01, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.380279, train acc: 0.888356, valid loss: 0.210206, valid acc: 0.935462
# Epoch: 20, train loss: 0.276081, train acc: 0.918285, valid loss: 0.149618, valid acc: 0.953804
# ===== Test Start =====
# Test loss: 0.150696, Test acc: 0.954127
# ===== Data: mnist, Model: second, Optimizer: sgd, lr: 0.1, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.167501, train acc: 0.948996, valid loss: 0.086584, valid acc: 0.972147
# Epoch: 20, train loss: 0.116697, train acc: 0.964732, valid loss: 0.064907, valid acc: 0.978601
# ===== Test Start =====
# Test loss: 0.069877, Test acc: 0.979267
# ===== Data: mnist, Model: second, Optimizer: adam, lr: 0.001, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.109294, train acc: 0.966257, valid loss: 0.060727, valid acc: 0.981658
# Epoch: 20, train loss: 0.072189, train acc: 0.977400, valid loss: 0.049401, valid acc: 0.985224
# ===== Test Start =====
# Test loss: 0.056558, Test acc: 0.983273
# ===== Data: mnist, Model: second, Optimizer: adam, lr: 0.01, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.108252, train acc: 0.967708, valid loss: 0.062000, valid acc: 0.983016
# Epoch: 20, train loss: 0.077483, train acc: 0.976228, valid loss: 0.057462, valid acc: 0.982846
# ===== Test Start =====
# Test loss: 0.061279, Test acc: 0.982772
# ===== Data: mnist, Model: second, Optimizer: adam, lr: 0.1, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.185324, train acc: 0.948828, valid loss: 0.097868, valid acc: 0.972996
# Epoch: 20, train loss: 0.154994, train acc: 0.957254, valid loss: 0.072274, valid acc: 0.979789
# ===== Test Start =====
# Test loss: 0.083261, Test acc: 0.978065
# ===== Data: mnist, Model: second, Optimizer: RMSprop, lr: 0.001, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.107703, train acc: 0.967299, valid loss: 0.063755, valid acc: 0.980808
# Epoch: 20, train loss: 0.075474, train acc: 0.976618, valid loss: 0.052624, valid acc: 0.984545
# ===== Test Start =====
# Test loss: 0.057789, Test acc: 0.982472
# ===== Data: mnist, Model: second, Optimizer: RMSprop, lr: 0.01, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.104812, train acc: 0.968750, valid loss: 0.060699, valid acc: 0.983186
# Epoch: 20, train loss: 0.075501, train acc: 0.976953, valid loss: 0.051935, valid acc: 0.986583
# ===== Test Start =====
# Test loss: 0.061592, Test acc: 0.982973
# ===== Data: mnist, Model: second, Optimizer: RMSprop, lr: 0.1, max_epochs: 20 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.277375, train acc: 0.925391, valid loss: 0.115025, valid acc: 0.971467
# Epoch: 20, train loss: 0.221405, train acc: 0.940216, valid loss: 0.094369, valid acc: 0.976393
# ===== Test Start =====
# Test loss: 0.099725, Test acc: 0.975761

# %% [markdown]
# ####fmnist

# %%
ds = ["fmnist"]
models = ['base']
opts = ["sgd",'adam','RMSprop']
lrs = [0.001,0.01,0.1]
max_epochs = 25

# %%
for d in ds:
  for m in models:
    for opt in opts:
      for lr in lrs:
        model = get_model(model_name = m)
        trainer = Trainer(model=model, opt=opt, lr=lr)
        print(f"===== Data: {d}, Model: {m}, Optimizer: {opt}, lr: {lr}, max_epochs: {max_epochs} =====")
        trainer.train(data_name=d, train_loader=datas[d][0], valid_loader=datas[d][1], max_epochs=max_epochs)
        trainer.test(test_loader=datas[d][2])
# Out:
# ===== Data: fmnist, Model: base, Optimizer: sgd, lr: 0.001, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 2.062484, train acc: 0.452920, valid loss: 2.036728, valid acc: 0.470279
# Epoch: 20, train loss: 1.380896, train acc: 0.612742, valid loss: 1.360077, valid acc: 0.612942
# ===== Test Start =====
# Test loss: 1.147964, Test acc: 0.631911
# ===== Data: fmnist, Model: base, Optimizer: sgd, lr: 0.01, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.637267, train acc: 0.777102, valid loss: 0.635570, valid acc: 0.771060
# Epoch: 20, train loss: 0.505956, train acc: 0.825967, valid loss: 0.510348, valid acc: 0.823879
# ===== Test Start =====
# Test loss: 0.513634, Test acc: 0.821114
# ===== Data: fmnist, Model: base, Optimizer: sgd, lr: 0.1, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.376860, train acc: 0.863690, valid loss: 0.389901, valid acc: 0.858696
# Epoch: 20, train loss: 0.308167, train acc: 0.886105, valid loss: 0.327909, valid acc: 0.883322
# ===== Test Start =====
# Test loss: 0.354923, Test acc: 0.872897
# ===== Data: fmnist, Model: base, Optimizer: adam, lr: 0.001, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.309498, train acc: 0.888132, valid loss: 0.348011, valid acc: 0.872622
# Epoch: 20, train loss: 0.251766, train acc: 0.908464, valid loss: 0.361158, valid acc: 0.874830
# ===== Test Start =====
# Test loss: 0.349148, Test acc: 0.878305
# ===== Data: fmnist, Model: base, Optimizer: adam, lr: 0.01, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.282645, train acc: 0.895424, valid loss: 0.350120, valid acc: 0.876868
# Epoch: 20, train loss: 0.236222, train acc: 0.911124, valid loss: 0.381867, valid acc: 0.877378
# ===== Test Start =====
# Test loss: 0.401125, Test acc: 0.873598
# ===== Data: fmnist, Model: base, Optimizer: adam, lr: 0.1, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 1.581867, train acc: 0.294048, valid loss: 1.627558, valid acc: 0.259511
# Epoch: 20, train loss: 1.728830, train acc: 0.194792, valid loss: 1.729342, valid acc: 0.192935
# ===== Test Start =====
# Test loss: 1.753144, Test acc: 0.198518
# ===== Data: fmnist, Model: base, Optimizer: RMSprop, lr: 0.001, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.313572, train acc: 0.884598, valid loss: 0.340935, valid acc: 0.876868
# Epoch: 20, train loss: 0.251550, train acc: 0.905636, valid loss: 0.324422, valid acc: 0.884511
# ===== Test Start =====
# Test loss: 0.349194, Test acc: 0.877103
# ===== Data: fmnist, Model: base, Optimizer: RMSprop, lr: 0.01, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.393305, train acc: 0.853757, valid loss: 0.411157, valid acc: 0.854280
# Epoch: 20, train loss: 0.352300, train acc: 0.870108, valid loss: 0.384139, valid acc: 0.869056
# ===== Test Start =====
# Test loss: 0.425213, Test acc: 0.854667
# ===== Data: fmnist, Model: base, Optimizer: RMSprop, lr: 0.1, max_epochs: 25 =====
# ===== Train Start =====
# Epoch: 10, train loss: 2.308077, train acc: 0.100632, valid loss: 2.310011, valid acc: 0.104110
# Epoch: 20, train loss: 2.308041, train acc: 0.099981, valid loss: 2.311709, valid acc: 0.097317
# ===== Test Start =====
# Test loss: 2.309107, Test acc: 0.100060

# %%
ds = ["fmnist"]
models = ['first','second']
opts = ["sgd",'adam','RMSprop']
lrs = [0.001,0.01,0.1]
max_epochs = 100

# %%
for d in ds:
  for m in models:
    for opt in opts:
      for lr in lrs:
        model = get_model(model_name = m)
        trainer = Trainer(model=model, opt=opt, lr=lr)
        print(f"===== Data: {d}, Model: {m}, Optimizer: {opt}, lr: {lr}, max_epochs: {max_epochs} =====")
        trainer.train(data_name=d, train_loader=datas[d][0], valid_loader=datas[d][1], max_epochs=max_epochs)
        trainer.test(test_loader=datas[d][2])
# Out:
# ===== Data: fmnist, Model: first, Optimizer: sgd, lr: 0.001, max_epochs: 100 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0
=====
# ===== Train Start =====
# Epoch: 10, train loss: 0.346457, train acc: 0.875614, valid loss: 0.317573, valid acc: 0.887908
# Epoch: 20, train loss: 0.293193, train acc: 0.895294, valid loss: 0.302567, valid acc: 0.892493
# Epoch: 30, train loss: 0.263539, train acc: 0.904148, valid loss: 0.286928, valid acc: 0.898438
# Epoch: 40, train loss: 0.242919, train acc: 0.912779, valid loss: 0.297002, valid acc: 0.892663
# Epoch: 50, train loss: 0.225455, train acc: 0.918731, valid loss: 0.284261, valid acc: 0.898777
# Epoch: 60, train loss: 0.208686, train acc: 0.924200, valid loss: 0.292514, valid acc: 0.900476
# Epoch: 70, train loss: 0.197994, train acc: 0.930022, valid loss: 0.299486, valid acc: 0.900815
# Epoch: 80, train loss: 0.187560, train acc: 0.933650, valid loss: 0.305171, valid acc: 0.897758
# Epoch: 90, train loss: 0.177840, train acc: 0.936682, valid loss: 0.307165, valid acc: 0.898947
# Epoch: 100, train loss: 0.166845, train acc: 0.940495, valid loss: 0.309487, valid acc: 0.903363
# ===== Test Start =====
# Test loss: 0.329555, Test acc: 0.897336
# ===== Data: fmnist, Model: second, Optimizer: RMSprop, lr: 0.1, max_epochs: 100 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.532558, train acc: 0.820368, valid loss: 0.415090, valid acc: 0.857677
# Epoch: 20, train loss: 0.470956, train acc: 0.838635, valid loss: 0.383551, valid acc: 0.866508
# Epoch: 30, train loss: 0.437245, train acc: 0.851786, valid loss: 0.355417, valid acc: 0.869735
# Epoch: 40, train loss: 0.413800, train acc: 0.859542, valid loss: 0.347513, valid acc: 0.870924
# Epoch: 50, train loss: 0.397476, train acc: 0.862240, valid loss: 0.370821, valid acc: 0.879076
# Epoch: 60, train loss: 0.382745, train acc: 0.867783, valid loss: 0.363179, valid acc: 0.880774
# Epoch: 70, train loss: 0.373490, train acc: 0.871503, valid loss: 0.347366, valid acc: 0.887568
# Epoch: 80, train loss: 0.365448, train acc: 0.874814, valid loss: 0.374830, valid acc: 0.867357
# Epoch: 90, train loss: 0.355295, train acc: 0.879055, valid loss: 0.351331, valid acc: 0.883152
# Epoch: 100, train loss: 0.349123, train acc: 0.879446, valid loss: 0.379333, valid acc: 0.880265
# ===== Test Start =====
# Test loss: 0.406254, Test acc: 0.872997

# %% [markdown]
# #MNIST 최종학습
# max epoch을 100으로 설정하여 학습하였을 때, 가장 성능이 좋았던 파라미터를 입력하였습니다.(max epoch를 100으로 설정하였을 때 어떤 파라미터가 최적인지 탐색하는 과정이 러닝타임 초기화로 인해 사라졌습니다. 그래서 시간관계상 max epoch을 20으로 주어서 학습을 진행해두었습니다.)

# %%
# MNIST dataset에 대해 여러분이 찾은 최적의 조건으로 학습을 한 번 더 진행해 주세요.
d = "mnist"
m = "first"
opt = "adam"
lr = 0.01
max_epochs = 100

model = get_model(model_name = m)
trainer = Trainer(model=model, opt=opt, lr=lr)
print(f"===== Data: {d}, Model: {m}, Optimizer: {opt}, lr: {lr}, max_epochs: {max_epochs} =====")
trainer.train(data_name=d, train_loader=datas[d][0], valid_loader=datas[d][1], max_epochs=max_epochs)
trainer.test(test_loader=datas[d][2])
# Out:
# ===== Data: mnist, Model: first, Optimizer: adam, lr: 0.01, max_epochs: 100 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.032488, train acc: 0.989174, valid loss: 0.063334, valid acc: 0.984885
# Epoch: 20, train loss: 0.019200, train acc: 0.993452, valid loss: 0.063804, valid acc: 0.986243
# Epoch: 30, train loss: 0.013804, train acc: 0.995443, valid loss: 0.067790, valid acc: 0.987772
# Epoch: 40, train loss: 0.014343, train acc: 0.995592, valid loss: 0.071908, valid acc: 0.983526
# Epoch: 50, train loss: 0.010318, train acc: 0.996782, valid loss: 0.076253, valid acc: 0.984885
# Epoch: 60, train loss: 0.010773, train acc: 0.996540, valid loss: 0.071412, valid acc: 0.986413
# Epoch: 70, train loss: 0.007833, train acc: 0.997786, valid loss: 0.080489, valid acc: 0.985904
# Epoch: 80, train loss: 0.006365, train acc: 0.997879, valid loss: 0.082461, valid acc: 0.986923
# Epoch: 90, train loss: 0.007945, train acc: 0.997675, valid loss: 0.095246, valid acc: 0.986923
# Epoch: 100, train loss: 0.006822, train acc: 0.998028, valid loss: 0.078383, valid acc: 0.987262
# ===== Test Start =====
# Test loss: 0.097001, Test acc: 0.985677

# %% [markdown]
# #FMNIST 최종학습

# %%
# FashionMNIST dataset에 대해 여러분이 찾은 최적의 조건으로 학습을 한 번 더 진행해 주세요.
d = "fmnist"
m = "second"
opt = "rmsprop"
lr = 0.001
max_epochs = 80

model = get_model(model_name = m)
trainer = Trainer(model=model, opt=opt, lr=lr)
print(f"===== Data: {d}, Model: {m}, Optimizer: {opt}, lr: {lr}, max_epochs: {max_epochs} =====")
trainer.train(data_name=d, train_loader=datas[d][0], valid_loader=datas[d][1], max_epochs=max_epochs)
trainer.test(test_loader=datas[d][2])
# Out:
# ===== Data: fmnist, Model: second, Optimizer: rmsprop, lr: 0.001, max_epochs: 80 =====
# ===== Train Start =====
# Epoch: 10, train loss: 0.342938, train acc: 0.876265, valid loss: 0.332960, valid acc: 0.877548
# Epoch: 20, train loss: 0.289653, train acc: 0.894271, valid loss: 0.301170, valid acc: 0.885870
# Epoch: 30, train loss: 0.259753, train acc: 0.905022, valid loss: 0.287783, valid acc: 0.890795
# Epoch: 40, train loss: 0.233794, train acc: 0.914230, valid loss: 0.294764, valid acc: 0.898777
# Epoch: 50, train loss: 0.212094, train acc: 0.923084, valid loss: 0.296286, valid acc: 0.896399
# Epoch: 60, train loss: 0.197786, train acc: 0.928423, valid loss: 0.289108, valid acc: 0.900815
# Epoch: 70, train loss: 0.182157, train acc: 0.934282, valid loss: 0.299580, valid acc: 0.900645
# Epoch: 80, train loss: 0.173052, train acc: 0.936514, valid loss: 0.293872, valid acc: 0.901664
# ===== Test Start =====
# Test loss: 0.299782, Test acc: 0.900741
